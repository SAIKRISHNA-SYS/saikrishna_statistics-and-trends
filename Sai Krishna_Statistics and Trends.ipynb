# %%
#IMPORTING ALL THE REQUIRED LIBRARIES
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Downloads\\mental_health_dataset.csv") # Reading data from csv file
data = df.sample(n=100) # storing the first hundred values of dataset in an variable named data

# %%
#cleaning data and pre-processing of data
data.dropna()
data.drop_duplicates()
# Out:
#      User_ID  Age             Gender   Occupation    Country  \
# 404      405   19         Non-binary  Engineering    Germany
# 581      582   26         Non-binary   Healthcare      Other
# 171      172   30             Female   Healthcare      India
# 376      377   43               Male      Finance    Germany
# 842      843   23  Prefer not to say  Engineering      India
# ..       ...  ...                ...          ...        ...
# 168      169   44         Non-binary           IT         UK
# 501      502   56             Female           IT      Other
# 647      648   56             Female    Education    Germany
# 86        87   36             Female    Education        USA
# 548      549   62             Female   Healthcare  Australia
#
#     Mental_Health_Condition Severity Consultation_History Stress_Level  \
# 404                      No      Low                  Yes          Low
# 581                     Yes      NaN                  Yes          Low
# ...

# %%
statistics_description = data.describe()
print(statistics_description)
# Out:
#           User_ID         Age  Sleep_Hours  Work_Hours  \
# count  100.000000  100.000000   100.000000  100.000000
# mean   494.860000   41.210000     7.091000   54.540000
# std    281.139852   14.429414     1.608632   15.419665
# min     26.000000   19.000000     4.000000   30.000000
# 25%    238.250000   28.000000     5.800000   41.000000
# 50%    505.500000   39.500000     7.150000   55.500000
# 75%    714.750000   55.000000     8.350000   68.250000
# max    987.000000   64.000000     9.900000   80.000000
#
#        Physical_Activity_Hours
# count               100.000000
# mean                  4.970000
# std                   3.112227
# min                   0.000000
# 25%                   2.000000
# 50%                   5.000000
# 75%                   7.250000
# max                  10.000000

# %%
    plt.figure(figsize=(10, 6)) # Defining Figure Size
    sns.histplot(data=data,x="Work_Hours",hue="Gender", multiple="stack",kde=True) # plotting histogram for type of work
    plt.xlabel("Work Hours") #Setting X Label
    plt.ylabel("Frequency") # Setting Y label
    plt.show() # showing the plot

# %%
    plt.figure(figsize=(10, 6)) # Defining Figure Size
    sns.scatterplot(data=data, x="Age", y="Work_Hours",hue ="Gender") # Plotting scatter plot
    plt.title("Age vs.Work Hours") # Setting Plot Title
    plt.xlabel("Age") # Setting X label
    plt.ylabel("Work Hours") # Setting Y label
    plt.show() # showing plot

# %%
# plotting of heatmap to understand the correaltion between the variables of data set
numeric_data = data.select_dtypes(include=['float64', 'int64'])
corr_matrix = numeric_data.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='crest')
plt.title("Correlation Matrix of Numeric Features")
plt.show()
